# %% [markdown]
# <a href="https://colab.research.google.com/github/abishekravi/DEEPLEARNING/blob/master/live_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zzh8829/yolov3-tf2
# %cd yolov3-tf2/
# !pip install -r requirements-gpu.txt
# Out:
# Cloning into 'yolov3-tf2'...
# remote: Enumerating objects: 380, done.
# remote: Total 380 (delta 0), reused 0 (delta 0), pack-reused 380
# Receiving objects: 100% (380/380), 4.17 MiB | 6.61 MiB/s, done.
# Resolving deltas: 100% (221/221), done.
# /content/yolov3-tf2
# Obtaining file:///content/yolov3-tf2 (from -r requirements-gpu.txt (line 6))
# Collecting tensorflow-gpu==2.1.0
#   Downloading https://files.pythonhosted.org/packages/0a/93/c7bca39b23aae45cd2e85ad3871c81eccc63b9c5276e926511e2e5b0879d/tensorflow_gpu-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 40kB/s
# Collecting opencv-python==4.1.1.26
#   Downloading https://files.pythonhosted.org/packages/5e/7e/bd5425f4dacb73367fddc71388a47c1ea570839197c2bcad86478e565186/opencv_python-4.1.1.26-cp36-cp36m-manylinux1_x86_64.whl (28.7MB)
#      |████████████████████████████████| 28.7MB 110kB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from -r requirements-gpu.txt (line 3)) (4.2.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r requirements-gpu.txt (line 4)) (4.41.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.8.1)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 54.3MB/s
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.4.1)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 51.3MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.29.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.18.5)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.2.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (47.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (2.23.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu==2.1.0->-r requirements-gpu.txt (line 1)) (0.4.8)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=d6c5b57fb7a6e44dcd6ffd23cb892797ea53df4ab34b1561a212d7e2d8862d48
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.1.1 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: gast, tensorflow-estimator, tensorboard, tensorflow-gpu, opencv-python, yolov3-tf2
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Running setup.py develop for yolov3-tf2
# Successfully installed gast-0.2.2 opencv-python-4.1.1.26 tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0 yolov3-tf2

# %%
# %cd yolov3-tf2/
# !ls

import tensorflow as tf
tf.__version__
# Out:
# [Errno 2] No such file or directory: 'yolov3-tf2/'
# /content/yolov3-tf2
# checkpoints	 data		  README.md		train.py
# colab_gpu.ipynb  detect.py	  requirements-gpu.txt	yolov3_tf2
# conda-cpu.yml	 detect_video.py  requirements.txt	yolov3_tf2.egg-info
# conda-gpu.yml	 docs		  setup.py
# convert.py	 LICENSE	  tools
# '2.1.0'

# %%
import time
from absl import app, flags, logging
from absl.flags import FLAGS
import cv2
import numpy as np
import tensorflow as tf
from yolov3_tf2.models import (
    YoloV3, YoloV3Tiny
)
from yolov3_tf2.dataset import transform_images, load_tfrecord_dataset
from yolov3_tf2.utils import draw_outputs

flags.DEFINE_string('classes', './data/coco.names', 'path to classes file')
flags.DEFINE_string('weights', './checkpoints/yolov3.tf',
                    'path to weights file')
flags.DEFINE_boolean('tiny', False, 'yolov3 or yolov3-tiny')
flags.DEFINE_integer('size', 416, 'resize images to')
flags.DEFINE_string('image', './data/girl.png', 'path to input image')
flags.DEFINE_string('tfrecord', None, 'tfrecord instead of image')
flags.DEFINE_string('output', './output.jpg', 'path to output image')
flags.DEFINE_integer('num_classes', 80, 'number of classes in the model')


def main(_argv):
    physical_devices = tf.config.experimental.list_physical_devices('GPU')
    for physical_device in physical_devices:
        tf.config.experimental.set_memory_growth(physical_device, True)

    if FLAGS.tiny:
        yolo = YoloV3Tiny(classes=FLAGS.num_classes)
    else:
        yolo = YoloV3(classes=FLAGS.num_classes)

    yolo.load_weights(FLAGS.weights).expect_partial()
    logging.info('weights loaded')

    class_names = [c.strip() for c in open(FLAGS.classes).readlines()]
    logging.info('classes loaded')

    if FLAGS.tfrecord:
        dataset = load_tfrecord_dataset(
            FLAGS.tfrecord, FLAGS.classes, FLAGS.size)
        dataset = dataset.shuffle(512)
        img_raw, _label = next(iter(dataset.take(1)))
    else:
        img_raw = tf.image.decode_image(
            open(FLAGS.image, 'rb').read(), channels=3)

    img = tf.expand_dims(img_raw, 0)
    img = transform_images(img, FLAGS.size)

    t1 = time.time()
    boxes, scores, classes, nums = yolo(img)
    t2 = time.time()
    logging.info('time: {}'.format(t2 - t1))

    logging.info('detections:')
    for i in range(nums[0]):
        logging.info('\t{}, {}, {}'.format(class_names[int(classes[0][i])],
                                           np.array(scores[0][i]),
                                           np.array(boxes[0][i])))

    img = cv2.cvtColor(img_raw.numpy(), cv2.COLOR_RGB2BGR)
    img = draw_outputs(img, (boxes, scores, classes, nums), class_names)
    cv2.imwrite(FLAGS.output, img)
    logging.info('output saved to: {}'.format(FLAGS.output))


if __name__ == '__main__':
    try:
        app.run(main)
    except SystemExit:
        pass

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O data/yolov3.weights
# !python convert.py
# Out:
# --2020-06-13 04:41:58--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘data/yolov3.weights’
#
# data/yolov3.weights 100%[===================>] 236.52M   909KB/s    in 4m 2s
#
# 2020-06-13 04:46:01 (1000 KB/s) - ‘data/yolov3.weights’ saved [248007048/248007048]
#
# 2020-06-13 04:46:04.370983: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-06-13 04:46:04.371086: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-06-13 04:46:04.371104: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2020-06-13 04:46:05.202221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-13 04:46:05.252236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:05.252873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-06-13 04:46:05.253193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:46:05.487167: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-13 04:46:05.601678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-13 04:46:05.631395: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-13 04:46:05.899118: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-13 04:46:05.937107: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-13 04:46:06.457083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:46:06.457280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.458015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.458576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-06-13 04:46:06.471574: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-06-13 04:46:06.477245: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-06-13 04:46:06.477463: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15de840 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-13 04:46:06.477493: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-13 04:46:06.595070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.595625: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15dea00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-13 04:46:06.595655: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-06-13 04:46:06.596461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.596881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-06-13 04:46:06.596950: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:46:06.596975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-13 04:46:06.596999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-13 04:46:06.597019: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-13 04:46:06.597044: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-13 04:46:06.597064: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-13 04:46:06.597084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:46:06.597157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.597557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.597924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-06-13 04:46:06.597989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:46:06.599157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-13 04:46:06.599184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-06-13 04:46:06.599196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-06-13 04:46:06.599305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.599709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:46:06.600091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# Model: "yolov3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, None, None,  0
# __________________________________________________________________________________________________
# yolo_darknet (Model)            ((None, None, None,  40620640    input[0][0]
# __________________________________________________________________________________________________
# yolo_conv_0 (Model)             (None, None, None, 5 11024384    yolo_darknet[1][2]
# __________________________________________________________________________________________________
# yolo_conv_1 (Model)             (None, None, None, 2 2957312     yolo_conv_0[1][0]
#                                                                  yolo_darknet[1][1]
# __________________________________________________________________________________________________
# yolo_conv_2 (Model)             (None, None, None, 1 741376      yolo_conv_1[1][0]
#                                                                  yolo_darknet[1][0]
# __________________________________________________________________________________________________
# yolo_output_0 (Model)           (None, None, None, 3 4984063     yolo_conv_0[1][0]
# __________________________________________________________________________________________________
# yolo_output_1 (Model)           (None, None, None, 3 1312511     yolo_conv_1[1][0]
# __________________________________________________________________________________________________
# yolo_output_2 (Model)           (None, None, None, 3 361471      yolo_conv_2[1][0]
# __________________________________________________________________________________________________
# yolo_boxes_0 (Lambda)           ((None, None, None,  0           yolo_output_0[1][0]
# __________________________________________________________________________________________________
# yolo_boxes_1 (Lambda)           ((None, None, None,  0           yolo_output_1[1][0]
# __________________________________________________________________________________________________
# yolo_boxes_2 (Lambda)           ((None, None, None,  0           yolo_output_2[1][0]
# __________________________________________________________________________________________________
# yolo_nms (Lambda)               ((None, 100, 4), (No 0           yolo_boxes_0[0][0]
#                                                                  yolo_boxes_0[0][1]
#                                                                  yolo_boxes_0[0][2]
#                                                                  yolo_boxes_1[0][0]
#                                                                  yolo_boxes_1[0][1]
#                                                                  yolo_boxes_1[0][2]
#                                                                  yolo_boxes_2[0][0]
#                                                                  yolo_boxes_2[0][1]
#                                                                  yolo_boxes_2[0][2]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# I0613 04:46:11.490142 140609198131072 convert.py:24] model created
# I0613 04:46:11.491690 140609198131072 utils.py:45] yolo_darknet/conv2d bn
# I0613 04:46:11.494514 140609198131072 utils.py:45] yolo_darknet/conv2d_1 bn
# I0613 04:46:11.497672 140609198131072 utils.py:45] yolo_darknet/conv2d_2 bn
# I0613 04:46:11.500344 140609198131072 utils.py:45] yolo_darknet/conv2d_3 bn
# I0613 04:46:11.502990 140609198131072 utils.py:45] yolo_darknet/conv2d_4 bn
# I0613 04:46:11.506534 140609198131072 utils.py:45] yolo_darknet/conv2d_5 bn
# I0613 04:46:11.509215 140609198131072 utils.py:45] yolo_darknet/conv2d_6 bn
# I0613 04:46:11.512104 140609198131072 utils.py:45] yolo_darknet/conv2d_7 bn
# I0613 04:46:11.514844 140609198131072 utils.py:45] yolo_darknet/conv2d_8 bn
# I0613 04:46:11.517684 140609198131072 utils.py:45] yolo_darknet/conv2d_9 bn
# I0613 04:46:11.522661 140609198131072 utils.py:45] yolo_darknet/conv2d_10 bn
# I0613 04:46:11.525486 140609198131072 utils.py:45] yolo_darknet/conv2d_11 bn
# I0613 04:46:11.529570 140609198131072 utils.py:45] yolo_darknet/conv2d_12 bn
# I0613 04:46:11.532288 140609198131072 utils.py:45] yolo_darknet/conv2d_13 bn
# I0613 04:46:11.536283 140609198131072 utils.py:45] yolo_darknet/conv2d_14 bn
# I0613 04:46:11.539119 140609198131072 utils.py:45] yolo_darknet/conv2d_15 bn
# I0613 04:46:11.543065 140609198131072 utils.py:45] yolo_darknet/conv2d_16 bn
# I0613 04:46:11.545800 140609198131072 utils.py:45] yolo_darknet/conv2d_17 bn
# I0613 04:46:11.549841 140609198131072 utils.py:45] yolo_darknet/conv2d_18 bn
# I0613 04:46:11.552625 140609198131072 utils.py:45] yolo_darknet/conv2d_19 bn
# I0613 04:46:11.556511 140609198131072 utils.py:45] yolo_darknet/conv2d_20 bn
# I0613 04:46:11.559212 140609198131072 utils.py:45] yolo_darknet/conv2d_21 bn
# I0613 04:46:11.563117 140609198131072 utils.py:45] yolo_darknet/conv2d_22 bn
# I0613 04:46:11.565797 140609198131072 utils.py:45] yolo_darknet/conv2d_23 bn
# I0613 04:46:11.569895 140609198131072 utils.py:45] yolo_darknet/conv2d_24 bn
# I0613 04:46:11.572726 140609198131072 utils.py:45] yolo_darknet/conv2d_25 bn
# I0613 04:46:11.576659 140609198131072 utils.py:45] yolo_darknet/conv2d_26 bn
# I0613 04:46:11.586359 140609198131072 utils.py:45] yolo_darknet/conv2d_27 bn
# I0613 04:46:11.589558 140609198131072 utils.py:45] yolo_darknet/conv2d_28 bn
# I0613 04:46:11.597880 140609198131072 utils.py:45] yolo_darknet/conv2d_29 bn
# I0613 04:46:11.601164 140609198131072 utils.py:45] yolo_darknet/conv2d_30 bn
# I0613 04:46:11.608985 140609198131072 utils.py:45] yolo_darknet/conv2d_31 bn
# I0613 04:46:11.612124 140609198131072 utils.py:45] yolo_darknet/conv2d_32 bn
# I0613 04:46:11.620040 140609198131072 utils.py:45] yolo_darknet/conv2d_33 bn
# I0613 04:46:11.623289 140609198131072 utils.py:45] yolo_darknet/conv2d_34 bn
# I0613 04:46:11.631538 140609198131072 utils.py:45] yolo_darknet/conv2d_35 bn
# I0613 04:46:11.635003 140609198131072 utils.py:45] yolo_darknet/conv2d_36 bn
# I0613 04:46:11.643203 140609198131072 utils.py:45] yolo_darknet/conv2d_37 bn
# I0613 04:46:11.646467 140609198131072 utils.py:45] yolo_darknet/conv2d_38 bn
# I0613 04:46:11.654381 140609198131072 utils.py:45] yolo_darknet/conv2d_39 bn
# I0613 04:46:11.657673 140609198131072 utils.py:45] yolo_darknet/conv2d_40 bn
# I0613 04:46:11.665713 140609198131072 utils.py:45] yolo_darknet/conv2d_41 bn
# I0613 04:46:11.669050 140609198131072 utils.py:45] yolo_darknet/conv2d_42 bn
# I0613 04:46:11.676958 140609198131072 utils.py:45] yolo_darknet/conv2d_43 bn
# I0613 04:46:11.717733 140609198131072 utils.py:45] yolo_darknet/conv2d_44 bn
# I0613 04:46:11.724507 140609198131072 utils.py:45] yolo_darknet/conv2d_45 bn
# I0613 04:46:11.754888 140609198131072 utils.py:45] yolo_darknet/conv2d_46 bn
# I0613 04:46:11.761615 140609198131072 utils.py:45] yolo_darknet/conv2d_47 bn
# I0613 04:46:11.791092 140609198131072 utils.py:45] yolo_darknet/conv2d_48 bn
# I0613 04:46:11.797337 140609198131072 utils.py:45] yolo_darknet/conv2d_49 bn
# I0613 04:46:11.826620 140609198131072 utils.py:45] yolo_darknet/conv2d_50 bn
# I0613 04:46:11.833139 140609198131072 utils.py:45] yolo_darknet/conv2d_51 bn
# I0613 04:46:11.862306 140609198131072 utils.py:45] yolo_conv_0/conv2d_52 bn
# I0613 04:46:11.867864 140609198131072 utils.py:45] yolo_conv_0/conv2d_53 bn
# I0613 04:46:11.897042 140609198131072 utils.py:45] yolo_conv_0/conv2d_54 bn
# I0613 04:46:11.905445 140609198131072 utils.py:45] yolo_conv_0/conv2d_55 bn
# I0613 04:46:11.935123 140609198131072 utils.py:45] yolo_conv_0/conv2d_56 bn
# I0613 04:46:11.940774 140609198131072 utils.py:45] yolo_output_0/conv2d_57 bn
# I0613 04:46:11.969872 140609198131072 utils.py:45] yolo_output_0/conv2d_58 bias
# I0613 04:46:11.972530 140609198131072 utils.py:45] yolo_conv_1/conv2d_59 bn
# I0613 04:46:11.975101 140609198131072 utils.py:45] yolo_conv_1/conv2d_60 bn
# I0613 04:46:11.977823 140609198131072 utils.py:45] yolo_conv_1/conv2d_61 bn
# I0613 04:46:11.984903 140609198131072 utils.py:45] yolo_conv_1/conv2d_62 bn
# I0613 04:46:11.987352 140609198131072 utils.py:45] yolo_conv_1/conv2d_63 bn
# I0613 04:46:11.994636 140609198131072 utils.py:45] yolo_conv_1/conv2d_64 bn
# I0613 04:46:11.996941 140609198131072 utils.py:45] yolo_output_1/conv2d_65 bn
# I0613 04:46:12.003909 140609198131072 utils.py:45] yolo_output_1/conv2d_66 bias
# I0613 04:46:12.005569 140609198131072 utils.py:45] yolo_conv_2/conv2d_67 bn
# I0613 04:46:12.007604 140609198131072 utils.py:45] yolo_conv_2/conv2d_68 bn
# I0613 04:46:12.009596 140609198131072 utils.py:45] yolo_conv_2/conv2d_69 bn
# I0613 04:46:12.012746 140609198131072 utils.py:45] yolo_conv_2/conv2d_70 bn
# I0613 04:46:12.014590 140609198131072 utils.py:45] yolo_conv_2/conv2d_71 bn
# I0613 04:46:12.017899 140609198131072 utils.py:45] yolo_conv_2/conv2d_72 bn
# I0613 04:46:12.019749 140609198131072 utils.py:45] yolo_output_2/conv2d_73 bn
# I0613 04:46:12.022748 140609198131072 utils.py:45] yolo_output_2/conv2d_74 bias
# I0613 04:46:12.023814 140609198131072 convert.py:27] weights loaded
# 2020-06-13 04:46:12.033302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:46:16.468518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# I0613 04:46:18.490029 140609198131072 convert.py:31] sanity check passed
# I0613 04:46:19.147728 140609198131072 convert.py:34] weights saved

# %%
# !ls
# Out:
# checkpoints	 data		  README.md		train.py
# colab_gpu.ipynb  detect.py	  requirements-gpu.txt	yolov3_tf2
# conda-cpu.yml	 detect_video.py  requirements.txt	yolov3_tf2.egg-info
# conda-gpu.yml	 docs		  setup.py
# convert.py	 LICENSE	  tools

# %%
# !python detect.py --image ./data/meme.jpg
# Out:
# 2020-06-13 04:48:18.360402: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-06-13 04:48:18.360513: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-06-13 04:48:18.360542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2020-06-13 04:48:19.187787: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-13 04:48:19.211198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.211834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-06-13 04:48:19.212133: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:48:19.213996: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-13 04:48:19.215710: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-13 04:48:19.216080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-13 04:48:19.217974: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-13 04:48:19.219121: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-13 04:48:19.222949: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:48:19.223067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.223674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.224138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-06-13 04:48:19.237933: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-06-13 04:48:19.244038: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-06-13 04:48:19.244937: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d36840 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-13 04:48:19.244971: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-13 04:48:19.339034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.339674: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1d36a00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-13 04:48:19.339710: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-06-13 04:48:19.339950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.340387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-06-13 04:48:19.340453: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:48:19.340484: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-13 04:48:19.340508: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-13 04:48:19.340534: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-13 04:48:19.340555: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-13 04:48:19.340575: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-13 04:48:19.340595: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:48:19.340668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.341135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.341482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-06-13 04:48:19.341542: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-13 04:48:19.342474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-13 04:48:19.342501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-06-13 04:48:19.342511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-06-13 04:48:19.342616: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.343058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-13 04:48:19.343425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# I0613 04:48:24.598084 139657734870912 detect.py:35] weights loaded
# I0613 04:48:24.598484 139657734870912 detect.py:38] classes loaded
# 2020-06-13 04:48:24.642850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-13 04:48:25.685459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# I0613 04:48:26.610404 139657734870912 detect.py:55] time: 1.9728152751922607
# I0613 04:48:26.610658 139657734870912 detect.py:57] detections:
# I0613 04:48:26.612779 139657734870912 detect.py:61] 	cup, 0.9980731010437012, [0.14266217 0.52777606 0.27184254 0.65748256]
# I0613 04:48:26.614597 139657734870912 detect.py:61] 	person, 0.9976975321769714, [0.28982916 0.09854656 0.95846486 0.9202166 ]
# I0613 04:48:26.616487 139657734870912 detect.py:61] 	laptop, 0.9846140146255493, [0.         0.39493686 0.5229729  0.7962776 ]
# I0613 04:48:26.618302 139657734870912 detect.py:61] 	apple, 0.9082659482955933, [0.13114461 0.77143586 0.22893354 0.90729535]
# I0613 04:48:26.620157 139657734870912 detect.py:61] 	chair, 0.7784969806671143, [0.2950731  0.3067718  0.9998861  0.99559444]
# I0613 04:48:26.622067 139657734870912 detect.py:61] 	cell phone, 0.7346776723861694, [0.18850097 0.87569416 0.3350185  0.9422209 ]
# I0613 04:48:26.623949 139657734870912 detect.py:61] 	clock, 0.6703543066978455, [0.4010809  0.21244611 0.49267417 0.35021502]
# I0613 04:48:26.754298 139657734870912 detect.py:66] output saved to: ./output.jpg

# %%
# !pwd
# Out:
# /content/yolov3-tf2

# %%
# !python detect_video.py --video -1
# Out:
# W0613 05:04:06.254096 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.354527 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.454848 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.555181 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.655626 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.756142 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.856589 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:06.957120 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.057474 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.157822 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.258129 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.358506 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.458805 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.559201 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.659667 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.760128 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.860450 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:07.960799 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.061132 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.161454 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.261782 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.362183 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.462494 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.562905 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.663231 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.763626 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.864055 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:08.964453 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.064870 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.165250 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.265663 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.366046 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.466496 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.566844 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.667159 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.767484 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.867882 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:09.968198 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.068574 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.169022 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.269375 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.369703 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.470043 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.570411 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.670821 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.771215 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.871676 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:10.972190 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.072638 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.173019 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.273352 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.373738 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.474135 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.574474 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.674807 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.775203 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.875609 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:11.976003 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.076325 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.176669 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.277025 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.377341 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.477727 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.578074 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.678386 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.778812 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.879208 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:12.979604 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.079968 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.180309 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.280673 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.381073 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.481425 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.581708 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.682008 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.782326 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.882837 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:13.983190 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.083517 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.183835 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.284213 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.384548 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.484945 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.585264 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.685598 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.786078 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.886527 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:14.986914 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.087269 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.187707 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.288081 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.388492 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.488801 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.589091 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.689393 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.789715 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.890103 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:15.990734 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.091092 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.191408 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.291840 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.392222 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.492580 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.592890 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.693244 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.793705 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.894235 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:16.994603 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.094926 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.195322 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.295727 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.396151 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.496624 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.597003 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.697425 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.797740 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.898077 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:17.998391 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.098691 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.199120 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.299541 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.399942 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.500307 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.600631 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.700986 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.801464 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:18.901943 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.002398 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.102729 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.203203 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.303667 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.404052 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.504409 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.604731 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.705139 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.805474 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:19.905849 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.006146 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.106477 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.206907 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.307260 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.407698 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.508127 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.608456 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.708940 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.809408 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:20.909831 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.010194 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.110531 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.211008 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.311452 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.411819 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.512157 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.612542 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.712934 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.813243 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:21.913714 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.014142 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.114453 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.214813 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.315187 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.415587 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.515910 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.616287 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.716636 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.817144 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:22.917602 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.018132 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.118519 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.218925 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.319353 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.419876 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.520322 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.620692 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.721127 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.821495 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:23.921891 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.022324 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.122658 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.223150 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.323524 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.423942 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.524251 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.624716 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.725240 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.825706 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:24.926143 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.026560 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.127002 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.227398 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.327826 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.428200 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.528556 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.628926 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.729283 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.829634 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:25.930050 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.030422 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.130887 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.231330 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.331786 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.432114 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.532466 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.632864 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.733258 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.833714 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:26.934116 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.034505 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.134857 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.235237 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.335601 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.436040 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.536405 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.636740 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.737162 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.837637 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:27.938185 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.038686 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.139095 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.239473 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.339851 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.440205 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.540566 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.640920 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.741336 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.841746 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:28.942225 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.042589 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.143003 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.243401 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.343817 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.444190 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.545871 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.646276 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.746649 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.847031 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:29.947360 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.047684 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.148134 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.248497 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.348858 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.449214 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.549577 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.650012 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.750436 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.850924 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:30.951332 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.051826 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.152192 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.252578 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.353097 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.453495 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.553965 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.654447 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.754823 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.855181 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:31.955533 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.055886 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.156265 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.256685 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.357233 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.457657 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.558135 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.658484 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.758856 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.859259 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:32.959637 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.060026 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.160383 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.260725 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.361198 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.461544 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.561930 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.662292 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.762678 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.863047 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:33.963356 140202230994816 detect_video.py:62] Empty Frame
# W0613 05:04:34.063691 140202230994816 detect_video.py:62] Empty Frame
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 299, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "detect_video.py", line 63, in main
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "detect_video.py", line 90, in <module>
#     app.run(main)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 312, in run
#     if FLAGS.pdb_post_mortem and sys.stdout.isatty():
#   File "/usr/local/lib/python3.6/dist-packages/absl/flags/_flagvalues.py", line 471, in __getattr__
#     fl = self._flags()
#   File "/usr/local/lib/python3.6/dist-packages/absl/flags/_flagvalues.py", line 142, in _flags
#     return self.__dict__['__flags']
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1fb449179546> in <module>()
# ----> 1 get_ipython().system('python detect_video.py --video -1')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
import sys
from absl import app, logging, flags
from absl.flags import FLAGS
import time
import cv2
import numpy as np
import tensorflow as tf
from yolov3_tf2.models import (
    YoloV3, YoloV3Tiny
)
from yolov3_tf2.dataset import transform_images, load_tfrecord_dataset
from yolov3_tf2.utils import draw_outputs

flags.DEFINE_string('classes', './data/coco.names', 'path to classes file')
flags.DEFINE_string('weights', './checkpoints/yolov3.tf',
                    'path to weights file')
flags.DEFINE_boolean('tiny', False, 'yolov3 or yolov3-tiny')
flags.DEFINE_integer('size', 416, 'resize images to')
flags.DEFINE_string('image', './data/girl.png', 'path to input image')
flags.DEFINE_string('tfrecord', None, 'tfrecord instead of image')
flags.DEFINE_string('output', './output.jpg', 'path to output image')
flags.DEFINE_integer('num_classes', 80, 'number of classes in the model')

app._run_init(['yolov3'], app.parse_flags_with_usage)

physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
FLAGS.image = 'data/meme.jpg'

if FLAGS.tiny:
    yolo = YoloV3Tiny(classes=FLAGS.num_classes)
else:
    yolo = YoloV3(classes=FLAGS.num_classes)
      
yolo.load_weights(FLAGS.weights).expect_partial()
logging.info('weights loaded')

class_names = [c.strip() for c in open(FLAGS.classes).readlines()]
logging.info('classes loaded')

img_raw = tf.image.decode_image(
    open(FLAGS.image, 'rb').read(), channels=3)

img = tf.expand_dims(img_raw, 0)
img = transform_images(img, FLAGS.size)

t1 = time.time()
boxes, scores, classes, nums = yolo(img)
t2 = time.time()
logging.info('time: {}'.format(t2 - t1))

logging.info('detections:')
for i in range(nums[0]):
    logging.info('\t{}, {}, {}'.format(class_names[int(classes[0][i])],
                                        np.array(scores[0][i]),
                                        np.array(boxes[0][i])))

img = cv2.cvtColor(img_raw.numpy(), cv2.COLOR_RGB2BGR)
img = draw_outputs(img, (boxes, scores, classes, nums), class_names)

from IPython.display import Image, display
display(Image(data=bytes(cv2.imencode('.jpg', img)[1]), width=800))
